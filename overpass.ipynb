# %%
import requests
import json
import pandas as pd
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-2"="DZ-15"][admin_level=4];
(node["amenity"="doctors"](area);
 way["amenity"="biergarten"](area);
 rel["amenity"="biergarten"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
import googlemaps   
import pandas as pd
gmaps = googlemaps.Client(key = 'AIzaSyCsmWSi1QEEnDyKib3C34Kk-04UGziKLL4')

lat_long = '36.69758304233767, 4.177324621480466'
places_result  = gmaps.places_nearby(location=lat_long, radius = 50000, open_now =False , type = 'doctor')

# %% [markdown]
# ### **location**
# The point around which to retrieve place information. This must be specified as `latitude,longitude`.

# %%
lat_long = '36.69758304233767, 4.177324621480466'
places_result  = gmaps.places_nearby(location=lat_long, radius = 50000, open_now =False , type = 'doctor')

# %%
# !pip3 python-geohash==0.8.5
# !pip3 install polygon-geohasher
# !pip3 install geopandas
# !pip3 install folium

import googlemaps   
import pandas as pd
import geopandas as gpd
import numpy as np
import json
import folium
gmaps = googlemaps.Client(key = 'AIzaSyCsmWSi1QEEnDyKib3C34Kk-04UGziKLL4')

lat_long = '36.69758304233767, 4.177324621480466'
places_result  = gmaps.places_nearby(location=lat_long, radius = 50000, open_now =False , type = 'doctor')
places = []
for place in places_result['results']:
    places.append([
        place['place_id'],
        place['vicinity'].split(',')[-1],
        place['name'],
        place['business_status'],
        place['geometry']['location']['lat'],
        
        
        place['geometry']['location']['lng'],
        # place['types'], 
    ])
    
df = pd.DataFrame(places, columns = ['place_id', 'vicinity', 'name', 'business_status', 'lat', 'lng'])
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.lng, df.lat), crs="EPSG:4326"
)
gdf
# Out:
#                        place_id              vicinity  \
# 0   ChIJF6Qtg8TnjRIRY9og_4PJuCA            Tizi Ouzou
# 1   ChIJNTKyXRPIjRIRcnavJvT4zKk            Tizi Ouzou
# 2   ChIJL-wNDw7IjRIRzYSbxdLp-80            Tizi Ouzou
# 3   ChIJZe_0E2zIjRIRA9epdCc6PsY            Tizi Ouzou
# 4   ChIJcRvNIYOmjRIR8IW4kYnIfDs                 Freha
# 5   ChIJ1cwhjMOxjRIR2OoRAIdtzp0           Tizi Rached
# 6   ChIJFYa4csWxjRIRdRoefoHSOdY           Tizi Rached
# 7   ChIJPx7BCe-xjRIRugS7SHnTUNM           Tizi Rached
# 8   ChIJea46rlu7jRIRFEPzxtKgsY8                 Freha
# 9   ChIJPf16xRW7jRIRYGxH459NRuc                 Freha
# 10  ChIJIYgl5Ke7jRIRtFtgzeZDENk                 Freha
# 11  ChIJGbRi8SG5jRIRjeZMOfpGNfs                 Freha
# 12  ChIJw918RiyxjRIRnBmBIgMOadk                Irdjen
# 13  ChIJA1mpz0GxjRIRZjHlvQXcimc   Larbaâ Nath Irathen
# 14  ChIJXY4jmZmxjRIRZpOQM_wdxJE   Larbaa Nath Irathen
# 15  ChIJBSp31suxjRIR567wigBHkZw   Larbaâ Nath Irathen
# ...

# %%
import folium

m = folium.Map(location=[36.69758304233767, 4.177324621480466], tiles="OpenStreetMap", zoom_start=9)

# %%
folium.GeoJson(gdf).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from polygon_geohasher.polygon_geohasher import geohash_to_polygon

locations = [(37.49786897152, 127.02764899362),
             (37.50732421875, 126.97998046875),
             (37.50732421875, 127.06787109375),
             (37.46337890625, 127.02392578125),
             (37.46337890625, 126.97998046875),
             (37.46337890625, 127.06787109375),
             (37.55126953125, 127.02392578125),
             (37.55126953125, 126.97998046875),
             (37.55126953125, 127.06787109375)]

# Create Geo Pandas DataFrame
df = gpd.GeoDataFrame({'location':locations, 'value': np.random.rand(9)})
df['geohash'] = df['location'].apply(lambda l: geohash.encode(l[0], l[1], 5))
df['geometry'] = df['geohash'].apply(geohash_to_polygon)
df.crs = {'init': 'epsg:4326'}


print('features.properties.geohash <- 요걸로 매핑함')
display(json.loads(df.to_json())['features'][0])
display(df.head())
# Out:
# features.properties.geohash <- 요걸로 매핑함
# /tmp/ipykernel_51135/4104714854.py:17: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   df['geometry'] = df['geohash'].apply(geohash_to_polygon)
# /usr/local/lib/python3.9/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# {'id': '0',
#  'type': 'Feature',
# ...

# %%
lat, lng = (37.497868971527424, 127.0276489936216) # 강남 Lat, Lng
m = folium.Map((lat, lng), zoom_start=12)
folium.Choropleth(geo_data=df, 
                  name='choropleth',
                  data=df,
                  columns=['geohash', 'value'],
                  key_on='feature.properties.geohash',
                  fill_color='YlGn',
                  fill_opacity=0.7,
                  line_opacity=0.2,
                  legend_name='asdf').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
idn_adm_bps_2020
# Out:
# ERROR: unknown command "python-geohash==0.8.5"

# %%
# Out:
# ...
#   Created wheel for polygon-geohasher: filename=polygon_geohasher-0.0.1-py3-none-any.whl size=4141 sha256=fba24d33277752dca3a9d9c7c1282c097b11be088e8a9e9f8fdf8641c7c5f9f6
#   Stored in directory: /root/.cache/pip/wheels/7f/bc/f1/da6151c47b3ee6d0590f44b4e8006dde85633725ecd630c6c8
# Successfully built polygon-geohasher
# ...

# %%
import geopandas as gpd
# shapefile = gpd.read_file('/datascience/idn_adm_bps_20200401_shp.zip')
shapefile.head()
# Out:
#    Shape_Leng  Shape_Area    ADM0_EN ADM0_PCODE  ADM0_REF  ADM0ALT1EN  \
# 0    910.2697  153.996361  Indonesia         ID       NaN         NaN
#
#    ADM0ALT2EN        date     validOn  validTo  \
# 0         NaN  2019-12-20  2020-04-01      NaN
#
#                                             geometry
# 0  MULTIPOLYGON (((122.87141 -10.96885, 122.87312...

# %%
import geopandas
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
# Out:
# /tmp/ipykernel_10414/3350786568.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
polygon = world[world['name'] =='Portugal']

# %%
center = [float(polygon.geometry.centroid.y), float(polygon.geometry.centroid.x)]
center
# Out:
# /tmp/ipykernel_10414/777666573.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [float(polygon.geometry.centroid.y), float(polygon.geometry.centroid.x)]
# [39.63404977497817, -8.055765588295687]

# %%
# get Kota Bogor polygon
# france = shapefile.loc[shapefile['ADM2_EN']=='Kota Bogor']['geometry'].values[0]

# create Kota Bogor map canvas
m= folium.Map(
  
  location=center,
  zoom_start=7,
  tiles="CartoDB Positron", # just my fav, refer to folium map terrain for more
)

folium.GeoJson(polygon).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from polygon_geohasher.polygon_geohasher import polygon_to_geohashes, geohashes_to_polygon
from shapely import geometry

# %%
polygon.geometry.values
# Out:
# <GeometryArray>
# [<POLYGON ((-9.035 41.881, -8.672 42.135, -8.264 42.28, -8.013 41.791, -7.423...>]
# Length: 1, dtype: geometry

# %%
inner_geohashes_polygon = polygon_to_geohashes(polygon.geometry.values, 7)

# outer_geohashes_polygon = geohashes_to_polygon(polygon_to_geohashes(polygon, 7, False))
inner_geohashes_polygon
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3460: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# create Kota Bogor map canvas
m= folium.Map(
  
  location=center,
  zoom_start=7,
  tiles="CartoDB Positron", # just my fav, refer to folium map terrain for more
)

folium.GeoJson(inner_geohashes_polygon).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 9
#       1 # create Kota Bogor map canvas
#       2 m= folium.Map(
#       3
#       4   location=center,
#       5   zoom_start=7,
#       6   tiles="CartoDB Positron", # just my fav, refer to folium map terrain for more
#       7 )
# ----> 9 folium.GeoJson(inner_geohashes_polygon).add_to(m)
#      10 m
#
# File /usr/local/lib/python3.9/dist-packages/folium/features.py:643, in GeoJson.__init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     638         raise TypeError(
#     639             "Only Marker, Circle, and CircleMarker are supported as GeoJson marker types."
#     640         )
#     641 self.marker = marker
# --> 643 self.data = self.process_data(data)
#     645 if self.style or self.highlight:
# ...

# %%
import folium
import geohash
from polygon_geohasher.polygon_geohasher import geohash_to_polygon

locations = [(37.49786897152, 127.02764899362),
             (37.50732421875, 126.97998046875),
             (37.50732421875, 127.06787109375),
             (37.46337890625, 127.02392578125),
             (37.46337890625, 126.97998046875),
             (37.46337890625, 127.06787109375),
             (37.55126953125, 127.02392578125),
             (37.55126953125, 126.97998046875),
             (37.55126953125, 127.06787109375)]

# Create Geo Pandas DataFrame
df = gpd.GeoDataFrame({'location':locations, 'value': np.random.rand(9)})
df['geohash'] = df['location'].apply(lambda l: geohash.encode(l[0], l[1], 5))
df['geometry'] = df['geohash'].apply(geohash_to_polygon)
df.crs = {'init': 'epsg:4326'}


print('features.properties.geohash <- 요걸로 매핑함')
display(json.loads(df.to_json())['features'][0])
display(df.head())
# Out:
# features.properties.geohash <- 요걸로 매핑함
# /tmp/ipykernel_10414/4104714854.py:17: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   df['geometry'] = df['geohash'].apply(geohash_to_polygon)
# /usr/local/lib/python3.9/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# {'id': '0',
#  'type': 'Feature',
# ...
